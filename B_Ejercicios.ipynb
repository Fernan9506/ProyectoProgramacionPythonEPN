# %%
# Para este proyecto se va utilizar pandas , numpy y matplotlib.pyplot
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#Lectura de Archivo de Analisis
path = "./forbes.csv"
datos = pd.read_csv(path)
datos.head()
# Out:
#                       Company      Sector             Industry      Continent  \
# 0                        ICBC  Financials          Major Banks           Asia
# 1     China Construction Bank  Financials       Regional Banks           Asia
# 2  Agricultural Bank of China  Financials       Regional Banks           Asia
# 3              JPMorgan Chase  Financials          Major Banks  North America
# 4          Berkshire Hathaway  Financials  Investment Services  North America
#
#          Country  Market Value  Sales  Profits  Assets  Rank  \
# 0          China         215.6  148.7     42.7  3124.9     1
# 1          China         174.4  121.3     34.2  2449.5     2
# 2          China         141.1  136.4     27.0  2405.4     3
# 3  United States         229.7  105.7     17.3  2435.3     4
# 4  United States         309.1  178.8     19.5   493.4     5
#
#                                       Forbes Webpage
# 0              http://www.forbes.com/companies/icbc/
# 1  http://www.forbes.com/companies/china-construc...
# 2  http://www.forbes.com/companies/agricultural-b...
# 3    http://www.forbes.com/companies/jpmorgan-chase/
# 4  http://www.forbes.com/companies/berkshire-hath...

# %%
# 1 Ejercicio Listar Numero de Empresas de cada Sector
sectores=(datos.groupby("Sector").agg(Frecuencia=("Sector", "count")))
sectores.plot(kind='bar', title= "Número Empresas por Sector")
plt.show()

# %%
# 1 Ejercicio Listar Numero de Empresas de cada Continente
sectores=(datos.groupby("Continent").agg(Frecuencia=("Continent", "count")))
sectores.plot(kind='bar', title= "Número Empresas por Continente")
plt.show()

# %%
# Listar la empresa top 1, adicional el promedio de todos los valores numericos, 
# suma del total de Ventas y Activos del ranking
print('****************** Empresa Numero 1 *******************')
print(datos.loc[0])
print('*********** Medias de los Valores Numéricos ***********')
print(datos.mean())
print('****************** Ventas y Activos *******************')
print('Ventas Totales: ',sum(datos['Sales']), 'Billones de $')
print('Activos Totales: ',sum(datos['Assets']), 'Billones de $')
print('*************** Estadística de la Data ****************')
print(datos.describe())
# Out:
# ****************** Empresa Numero 1 *******************
# Company                                            ICBC
# Sector                                       Financials
# Industry                                    Major Banks
# Continent                                          Asia
# Country                                           China
# Market Value                                      215.6
# Sales                                             148.7
# Profits                                            42.7
# Assets                                           3124.9
# Rank                                                  1
# Forbes Webpage    http://www.forbes.com/companies/icbc/
# Name: 0, dtype: object
# *********** Medias de los Valores Numéricos ***********
# Market Value      22.20515
# Sales             19.18050
# Profits            1.46375
# Assets            80.48720
# Rank            1000.32450
# dtype: float64
# ****************** Ventas y Activos *******************
# Ventas Totales:  38360.99999999978 Billones de $
# Activos Totales:  160974.39999999967 Billones de $
# *************** Estadística de la Data ****************
#        Market Value        Sales      Profits       Assets         Rank
# count   2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean      22.205150    19.180500     1.463750    80.487200  1000.324500
# std       37.077202    34.695518     3.962383   256.077169   577.397506
# min        0.000000     0.000000   -13.400000     0.700000     1.000000
# 25%        5.900000     4.200000     0.300000    10.200000   500.750000
# 50%       10.750000     9.200000     0.600000    19.950000  1000.500000
# 75%       22.125000    18.825000     1.300000    46.600000  1499.500000
# max      483.100000   476.500000    84.000000  3270.100000  1999.000000

# %%
# Listar todas las empresas que sus ventas sean mayores a 100 billones y menores a 150
datosVentas = pd.DataFrame(datos, columns=['Company','Industry','Continent','Country','Sales'])
datosVentas = datosVentas[(datosVentas.Sales>=100) & (datosVentas.Sales<=200)]
datosVentas
# Out:
#                         Company                     Industry      Continent  \
# 0                          ICBC                  Major Banks           Asia
# 1       China Construction Bank               Regional Banks           Asia
# 2    Agricultural Bank of China               Regional Banks           Asia
# 3                JPMorgan Chase                  Major Banks  North America
# 4            Berkshire Hathaway          Investment Services  North America
# 6              General Electric                Conglomerates  North America
# 8                 Bank of China                  Major Banks           Asia
# 12              Bank of America                  Major Banks  North America
# 14                        Apple            Computer Hardware  North America
# 20                      Gazprom         Oil & Gas Operations           Asia
# 22                         AT&T  Telecommunications services  North America
# 23                  BNP Paribas                  Major Banks         Europe
# 25       Verizon Communications  Telecommunications services  North America
# 26                      Allianz        Diversified Insurance         Europe
# 27                 China Mobile  Telecommunications services           Asia
# 29                    Petrobras         Oil & Gas Operations  South America
# 30                      Daimler   Auto & Truck Manufacturers         Europe
# 32                    AXA Group        Diversified Insurance         Europe
# 33                      Rosneft         Oil & Gas Operations           Asia
# 38                          Eni         Oil & Gas Operations         Europe
# 46                   Ford Motor   Auto & Truck Manufacturers  North America
# 47                    BMW Group   Auto & Truck Manufacturers         Europe
# 49                          EDF           Electric Utilities         Europe
# 50                      Statoil         Oil & Gas Operations         Europe
# 60       Nippon Telegraph & Tel  Telecommunications services           Asia
# 66               General Motors   Auto & Truck Manufacturers  North America
# 69                  Honda Motor   Auto & Truck Manufacturers           Asia
# 70                         Enel           Electric Utilities         Europe
# 79              Hewlett-Packard            Computer Hardware  North America
# 82                       LukOil         Oil & Gas Operations           Asia
# 85           UnitedHealth Group          Managed Health Care  North America
# 95                 CVS Caremark                  Drug Retail  North America
# 110                Nissan Motor   Auto & Truck Manufacturers           Asia
# 112                        E.ON           Electric Utilities         Europe
# 113              Generali Group        Diversified Insurance         Europe
# 138           Hon Hai Precision                  Electronics           Asia
# 139                 Phillips 66         Oil & Gas Operations  North America
# 158             Express Scripts          Healthcare Services  North America
# 178               Valero Energy         Oil & Gas Operations  North America
# 216            Costco Wholesale              Discount Stores  North America
# 243                    McKesson              Pharmaceuticals  North America
# 255                        EXOR          Investment Services         Europe
# 281                 JX Holdings         Oil & Gas Operations           Asia
# 354                  Fannie Mae          Investment Services  North America
# 404                    GDF SUEZ           Electric Utilities         Europe
# 465                       Tesco                  Food Retail         Europe
# 665                 SK Holdings         Oil & Gas Operations           Asia
#
#             Country  Sales
# 0             China  148.7
# 1             China  121.3
# 2             China  136.4
# 3     United States  105.7
# 4     United States  178.8
# 6     United States  143.3
# 8             China  105.1
# 12    United States  101.5
# 14    United States  173.8
# 20           Russia  164.6
# 22    United States  128.8
# 23           France  123.2
# 25    United States  120.6
# 26          Germany  131.4
# 27        Hong Kong  102.5
# 29           Brazil  141.2
# 30          Germany  156.6
# 32           France  138.9
# 33           Russia  142.6
# 38            Italy  152.7
# 46    United States  146.9
# 47          Germany  101.0
# 49           France  100.4
# 50           Norway  105.2
# 60            Japan  110.7
# 66    United States  155.4
# 69            Japan  117.7
# 70            Italy  106.3
# 79    United States  112.1
# 82           Russia  119.2
# 85    United States  122.5
# 95    United States  126.8
# 110           Japan  104.0
# 112         Germany  162.6
# 113           Italy  100.5
# 138          Taiwan  127.2
# 139   United States  157.9
# 158   United States  104.2
# 178   United States  138.1
# 216   United States  107.9
# 243   United States  130.1
# 255           Italy  143.7
# 281           Japan  124.6
# 354   United States  122.9
# 404          France  118.6
# 465  United Kingdom  100.6
# 665     South Korea  102.2

# %%
# 3 Ejercicio Listar Numero de Empresas de cada Continente del Ejercicio Anterior
continentes=(datosVentas.groupby("Continent").agg(Frecuencia=("Continent", "count")))
print(continentes)
contin='Asia','Europa','Norte America','Sur America'
explode = (0.1, 0, 0.1, 0.1)
fig1, ax1 = plt.subplots()
ax1.pie(np.array(continentes.values).ravel(), explode=explode, labels=contin, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')
plt.show()
# Out:
#                Frecuencia
# Continent
# Asia                   14
# Europe                 14
# North America          18
# South America           1

# %%
# 4 Ejercicio Listar Numero de Empresas de cada Pais del Ejercicio Anterior
paises=(datosVentas.groupby("Country").agg(Frecuencia=("Country", "count")))
paises.plot(kind='bar')
plt.show()

# %%
# 5 Graficar todas las ventas de estos paises
ventasGraf=(pd.DataFrame(datosVentas, columns=['Company','Sales']))
ventasGraf.plot(title="Grafico de Ventas")
plt.show()

# %%
# 5 Graficar todas las ventas de estos paises
ventasGraf=(pd.DataFrame(datosVentas, columns=['Company','Sales']))
ventasGraf.plot(kind='bar',title="Grafico de Ventas ")
plt.show()

# %%
# Listar la empresa top 1, adicional el promedio de todos los valores numericos, 
# suma del total de Ventas y Activos del ranking
print('****************** Empresa Numero 1 *******************')
print(datosVentas.loc[0])
print('*********** Medias de los Valores Numéricos ***********')
print(datosVentas.mean())
print('****************** Ventas *******************')
print('Ventas Totales: ',sum(datosVentas['Sales']), 'Billones de $')
print('*************** Estadística de la Data ****************')
print(datosVentas.describe())
# Out:
# ****************** Empresa Numero 1 *******************
# Company             ICBC
# Industry     Major Banks
# Continent           Asia
# Country            China
# Sales              148.7
# Name: 0, dtype: object
# *********** Medias de los Valores Numéricos ***********
# Sales    127.382979
# dtype: float64
# ****************** Ventas *******************
# Ventas Totales:  5987.0 Billones de $
# *************** Estadística de la Data ****************
#             Sales
# count   47.000000
# mean   127.382979
# std     21.781008
# min    100.400000
# 25%    106.000000
# 50%    123.200000
# 75%    142.950000
# max    178.800000
